# %% [markdown]
# Group B: Assignments based on Data Analytics using Python

# %% [raw]
# "4. Perform the following operations using Python on the Facebook metrics data sets"
#
# a. Create data subsets
# b. Merge Data
# c. Sort Data
# d. Transposing Data
# e. Shape and reshape Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset_Facebook.csv",delimiter=";")
df.ta(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# a. Create data subsets

# %%
df1= df[["Page total likes","Type","Category","Post Month","Post Weekday"]].loc[0:10]
df1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 0             139441   Photo         2          12             4
# 1             139441  Status         2          12             3
# 2             139441   Photo         3          12             3
# 3             139441   Photo         2          12             2
# 4             139441   Photo         2          12             2
# 5             139441  Status         2          12             1
# 6             139441   Photo         3          12             1
# 7             139441   Photo         3          12             7
# 8             139441  Status         2          12             7
# 9             139441   Photo         3          12             6
# 10            139441  Status         2          12             5

# %%
df2=df[["Page total likes","Type","Category","Post Month","Post Weekday"]].loc[21:25]
df2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 21            138414   Photo         1          12             7
# 22            138414    Link         1          12             7
# 23            138414   Photo         3          12             7
# 24            138414  Status         2          12             6
# 25            138458  Status         2          12             6

# %%
df3=df[["Page total likes","Type","Category","Post Month","Post Weekday"]].loc[31:38]
df3
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 31            138895   Photo         2          12             3
# 32            138895   Photo         3          12             3
# 33            138895   Photo         3          12             2
# 34            138895   Photo         1          12             2
# 35            138895   Photo         2          12             1
# 36            138895   Photo         3          12             1
# 37            138895   Photo         1          12             7
# 38            138895  Status         2          12             7

# %% [markdown]
# b. Merge Data

# %%
pd.concat([df1,df2,df3])
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 0             139441   Photo         2          12             4
# 1             139441  Status         2          12             3
# 2             139441   Photo         3          12             3
# 3             139441   Photo         2          12             2
# 4             139441   Photo         2          12             2
# 5             139441  Status         2          12             1
# 6             139441   Photo         3          12             1
# 7             139441   Photo         3          12             7
# 8             139441  Status         2          12             7
# 9             139441   Photo         3          12             6
# 10            139441  Status         2          12             5
# 21            138414   Photo         1          12             7
# 22            138414    Link         1          12             7
# ...

# %% [markdown]
# c. Sort Data

# %%
df1.sort_values(by = ["Post Weekday"])
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 5             139441  Status         2          12             1
# 6             139441   Photo         3          12             1
# 3             139441   Photo         2          12             2
# 4             139441   Photo         2          12             2
# 1             139441  Status         2          12             3
# 2             139441   Photo         3          12             3
# 0             139441   Photo         2          12             4
# 10            139441  Status         2          12             5
# 9             139441   Photo         3          12             6
# 7             139441   Photo         3          12             7
# 8             139441  Status         2          12             7

# %%
df1.sort_values("Category", ascending=True)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday
# 0             139441   Photo         2          12             4
# 1             139441  Status         2          12             3
# 3             139441   Photo         2          12             2
# 4             139441   Photo         2          12             2
# 5             139441  Status         2          12             1
# 8             139441  Status         2          12             7
# 10            139441  Status         2          12             5
# 2             139441   Photo         3          12             3
# 6             139441   Photo         3          12             1
# 7             139441   Photo         3          12             7
# 9             139441   Photo         3          12             6

# %% [markdown]
# d. Transposing Data

# %%
df1.transpose()
# Out:
#                       0       1       2       3       4       5       6   \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                       7       8       9       10
# Page total likes  139441  139441  139441  139441
# Type               Photo  Status   Photo  Status
# Category               3       2       3       2
# Post Month            12      12      12      12
# Post Weekday           7       7       6       5

# %% [markdown]
# e. Shape and reshape Data

# %%
df1.shape
# Out:
# (11, 5)

# %%
fdf=df1.values.reshape(11,5)

# %%
pd.DataFrame(fdf)
# Out:
#          0       1  2   3  4
# 0   139441   Photo  2  12  4
# 1   139441  Status  2  12  3
# 2   139441   Photo  3  12  3
# 3   139441   Photo  2  12  2
# 4   139441   Photo  2  12  2
# 5   139441  Status  2  12  1
# 6   139441   Photo  3  12  1
# 7   139441   Photo  3  12  7
# 8   139441  Status  2  12  7
# 9   139441   Photo  3  12  6
# 10  139441  Status  2  12  5

# %%
fdf.shape
# Out:
# (11, 5)
